# %%
import numpy as np
a=np.array([20,40,50,60])
print(np.sum(a))
print(np.max(a))
print(np.min(a))
print(np.size(a))
print(np.mean(a))
print(np.cumsum(a))
print(np.cumprod(a))
# Out:
# 170
# 60
# 20
# 4
# 42.5
# [ 20  60 110 170]
# [     20     800   40000 2400000]
