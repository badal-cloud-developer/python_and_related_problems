# %%
import pandas as pd
data={"Name":["badal","barsha","bijuli"],
      "Age":[20,21,34],
      "Salary":[30000,50000,55000]}

df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Salary
# 0   badal   20   30000
# 1  barsha   21   50000
# 2  bijuli   34   55000

# %%
#to call a excel fie and csv file

data=pd.read_csv("hotel_booking.csv") 
print(data)                             #you can give path also
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
datas=pd.read_excel("Vrinda_Store_Raw_ Data.xlsx") 
print(datas)
# Out:
#        index             Order ID  Cust ID Gender  Age   Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44  44899  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29  44899  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67  44899  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20  44899  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62  44899  Delivered
# ...      ...                  ...      ...    ...  ...    ...        ...
# 31042  31043  405-4724097-1016369  4724097      M   60  44567  Delivered
# 31043  31044  405-4724097-1016369  4724097      M   34  44567  Delivered
# 31044  31045  408-3572295-5992330  3572295      M   29  44567  Delivered
# 31045  31046  405-1423498-9705162  1423498      M   46  44567  Delivered
# 31046  31047  408-4694875-8249153  4694875      M   36  44567  Delivered
#
#        Channel                       SKU       Category Size  Qty currency  \
# ...
