# %%
import pandas as pd
data=pd.read_excel("Vrinda_Store_Raw_ Data.xlsx")
#print(data)

print(data.head(10))
print(data.tail(10))
# Out:
#    index             Order ID  Cust ID Gender  Age   Date     Status  \
# 0      1  171-1029312-3038738  1029312  Women   44  44899  Delivered
# 1      2  405-2183842-2225946  2183842  Women   29  44899  Delivered
# 2      3  171-1641533-8921966  1641533  Women   67  44899  Delivered
# 3      4  404-7490807-6300351  7490807  Women   20  44899  Delivered
# 4      5  403-9293516-4577154  9293516  Women   62  44899  Delivered
# 5      6  407-1298130-0368305  1298130    Men   49  44899  Delivered
# 6      7  407-1298130-0368305  1298130      W   23  44899  Delivered
# 7      8  171-5561216-3398711  5561216      W   70  44899  Delivered
# 8      9  408-2935263-2935550  2935263      W   75  44899  Delivered
# 9     10  404-2648970-9042715  2648970      W   43  44899  Delivered
#
#    Channel                       SKU       Category Size  Qty currency  \
# 0    Myntra  JNE1233-BLUE-KR-031-XXL          kurta  XXL    1      INR
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  str
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  str
#  4   Age               31047 non-null  int64
#  5   Date              31047 non-null  int64
#  6   Status            31047 non-null  str
#  7   Channel           31047 non-null  str
#  8   SKU               31047 non-null  str
#  9   Category          31047 non-null  str
#  10  Size              31047 non-null  str
#  11  Qty               31047 non-null  object
#  12  currency          31047 non-null  str
#  13  Amount            31047 non-null  int64
#  14  ship-city         31047 non-null  str
#  15  ship-state        31047 non-null  str
#  16  ship-postal-code  31047 non-null  int64
# ...

# %%
print(data.isnull().sum())  #column wise null value ko sum dinxa
# Out:
# index               0
# Order ID            0
# Cust ID             0
# Gender              0
# Age                 0
# Date                0
# Status              0
# Channel             0
# SKU                 0
# Category            0
# Size                0
# Qty                 0
# currency            0
# Amount              0
# ship-city           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# B2B                 0
# dtype: int64

# %%
data.describe() #data ko different statistical information haru dinxa
# Out:
#              index       Cust ID           Age          Date        Amount  \
# count  31047.00000  3.104700e+04  31047.000000  31047.000000  31047.000000
# mean   15524.00000  4.936824e+06     39.496570  44727.278932    682.074822
# std     8962.64124  2.900678e+06     15.117233    104.513445    268.582173
# min        1.00000  8.950000e+02     18.000000  44565.000000    229.000000
# 25%     7762.50000  2.416471e+06     28.000000  44626.000000    486.000000
# 50%    15524.00000  4.909885e+06     37.000000  44718.000000    646.000000
# 75%    23285.50000  7.454182e+06     47.000000  44810.000000    794.000000
# max    31047.00000  9.999233e+06     78.000000  44901.000000   3036.000000
#
#        ship-postal-code
# count      31047.000000
# mean      460474.587206
# std       198116.733009
# min       110001.000000
# 25%       313001.000000
# 50%       500028.000000
# 75%       600040.000000
# max       855117.000000
